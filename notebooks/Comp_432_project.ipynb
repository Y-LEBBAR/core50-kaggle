# %%
# !git clone https://github.com/Y-LEBBAR/core50-kaggle.git
# %cd core50-kaggle
# Out:
# Cloning into 'core50-kaggle'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 18 (delta 2), reused 17 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), 7.25 KiB | 2.42 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /content/core50-kaggle

# %%
# !pip install torch pandas numpy scikit-learn --quiet

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-22b73bfb-958d-4ada-b354-31d5be0ab53e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-22b73bfb-958d-4ada-b354-31d5be0ab53e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os, shutil

os.makedirs("data", exist_ok=True)

shutil.move("train.csv", "data/train.csv")
shutil.move("test.csv", "data/test.csv")
shutil.move("sample_submission.csv", "data/sample_submission.csv")
# Out:
# 'data/sample_submission.csv'

# %%
os.makedirs("models", exist_ok=True)

print("data/ ->", os.listdir("data"))
print("src/ ->", os.listdir("src"))
print("models/ ->", os.listdir("models"))
# Out:
# data/ -> ['test.csv', 'train.csv', 'sample_submission.csv']
# src/ -> ['model.py', 'data.py', 'predict.py', 'train.py', 'config.py', 'utils.py']
# models/ -> []

# %%
# !python src/train.py
# Out:
# Epoch [1/25] | Train Loss: 534.6545 | Val Acc: 0.3809
# --> New best model saved (val_acc=0.3809)
# Epoch [2/25] | Train Loss: 379.8635 | Val Acc: 0.4422
# --> New best model saved (val_acc=0.4422)
# Epoch [3/25] | Train Loss: 325.0412 | Val Acc: 0.4683
# --> New best model saved (val_acc=0.4683)
# Epoch [4/25] | Train Loss: 289.3100 | Val Acc: 0.4858
# --> New best model saved (val_acc=0.4858)
# Epoch [5/25] | Train Loss: 263.0253 | Val Acc: 0.4982
# --> New best model saved (val_acc=0.4982)
# Epoch [6/25] | Train Loss: 241.1695 | Val Acc: 0.5076
# --> New best model saved (val_acc=0.5076)
# Epoch [7/25] | Train Loss: 222.5592 | Val Acc: 0.5117
# --> New best model saved (val_acc=0.5117)
# Epoch [8/25] | Train Loss: 206.5926 | Val Acc: 0.5180
# --> New best model saved (val_acc=0.5180)
# Epoch [9/25] | Train Loss: 193.3413 | Val Acc: 0.5196
# --> New best model saved (val_acc=0.5196)
# Epoch [10/25] | Train Loss: 181.3736 | Val Acc: 0.5209
# ...

# %%
os.makedirs("submissions", exist_ok=True)

# %%
# !python src/predict.py
# Out:
# Submission file created at: submissions/submission.csv
# Total predictions: 49460

# %%
# !ls models
# Out:
# best_model.pth	mean_std.npz

# %%
files.download('submissions/submission.csv')
